# %%
import pandas as pd
import os
import requests
from bs4 import BeautifulSoup

# %%
path = os.getcwd()
df = pd.read_csv(path+'\csv\champions.csv',sep=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\JOOGON~1\AppData\Local\Temp/ipykernel_9072/2777104915.py in <module>
#       1 path = os.getcwd()
# ----> 2 df = pd.read_csv(path+'\\csv\champions.csv',sep=',')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# HTML SRACPING

URL = "https://universe.leagueoflegends.com/en_US/story/champion/Aatrox/"
page = requests.get(URL)
print(page.text)

soup = BeautifulSoup(page.content, "html.parser")
#print(soup)
results = soup.find_all(id='CatchElement')
#job_elements = results.find_all("p", class_="p_1_sJ")

#print(results.prettify())
print(results.text)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
#     <meta name="google-site-verification" content="-B5JjZpFsnhF1Pe52Kr2ydQQVNV9DTe6qr-Isauuthc" />
#     <meta name="theme-color" content="#0a0a0c">
#
#     <title>Universe of League of Legends</title>
# ...
